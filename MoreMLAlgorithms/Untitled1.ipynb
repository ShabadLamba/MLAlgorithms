# %% [markdown]
# Firing up GraphLab

# %%
import graphlab

# %% [markdown]
# Load some house data

# %%
sales = graphlab.SFrame("home_data.gl/")
# Out:
# 2016-05-29 22:54:04,035 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: /tmp/graphlab_server_1464542640.log
# This trial license of GraphLab Create is assigned to shabadlamba@gmail.com and will expire on June 28, 2016. Please contact trial@dato.com for licensing options or to request a free non-commercial license for personal or academic use.

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000 |    4     |     3     |     1960    |
# | 1954400510 | 2015-02-18 00:00:00+00:00 |  510000 |    3     |     2     |     1680    |
# | 7237550310 | 2014-05-12 00:00:00+00:00 | 1225000 |    4     |    4.5    |     5420    |
# | 1321400060 | 2014-06-27 00:00:00+00:00 |  257500 |    3     |    2.25   |     1715    |
# | 2008000270 | 2015-01-15 00:00:00+00:00 |  291850 |    3     |    1.5    |     1060    |
# | 2414600126 | 2015-04-15 00:00:00+00:00 |  229500 |    3     |     1     |     1780    |
# | 3793500160 | 2015-03-12 00:00:00+00:00 |  323000 |    3     |    2.5    |     1890    |
# +------------+---------------------------+---------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |   5650   |   1    |     0      |  0   |     3     |   7   |    1180    |       0       |
# |   7242   |   2    |     0      |  0   |     3     |   7   |    2170    |      400      |
# |  10000   |   1    |     0      |  0   |     3     |   6   |    770     |       0       |
# |   5000   |   1    |     0      |  0   |     5     |   7   |    1050    |      910      |
# |   8080   |   1    |     0      |  0   |     3     |   8   |    1680    |       0       |
# |  101930  |   1    |     0      |  0   |     3     |   11  |    3890    |      1530     |
# |   6819   |   2    |     0      |  0   |     3     |   7   |    1715    |       0       |
# |   9711   |   1    |     0      |  0   |     3     |   7   |    1060    |       0       |
# |   7470   |   1    |     0      |  0   |     3     |   7   |    1050    |      730      |
# |   6560   |   2    |     0      |  0   |     3     |   7   |    1890    |       0       |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1955   |      0       |  98178  | 47.51123398 | -122.25677536 |     1340.0    | ... |
# |   1951   |     1991     |  98125  | 47.72102274 |  -122.3188624 |     1690.0    | ... |
# |   1933   |      0       |  98028  | 47.73792661 | -122.23319601 |     2720.0    | ... |
# |   1965   |      0       |  98136  |   47.52082  | -122.39318505 |     1360.0    | ... |
# |   1987   |      0       |  98074  | 47.61681228 | -122.04490059 |     1800.0    | ... |
# |   2001   |      0       |  98053  | 47.65611835 | -122.00528655 |     4760.0    | ... |
# |   1995   |      0       |  98003  | 47.30972002 | -122.32704857 |     2238.0    | ... |
# |   1963   |      0       |  98198  | 47.40949984 | -122.31457273 |     1650.0    | ... |
# |   1960   |      0       |  98146  | 47.51229381 | -122.33659507 |     1780.0    | ... |
# |   2003   |      0       |  98038  | 47.36840673 |  -122.0308176 |     2390.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [21613 rows x 21 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000 |    4     |     3     |     1960    |
# | 1954400510 | 2015-02-18 00:00:00+00:00 |  510000 |    3     |     2     |     1680    |
# | 7237550310 | 2014-05-12 00:00:00+00:00 | 1225000 |    4     |    4.5    |     5420    |
# | 1321400060 | 2014-06-27 00:00:00+00:00 |  257500 |    3     |    2.25   |     1715    |
# | 2008000270 | 2015-01-15 00:00:00+00:00 |  291850 |    3     |    1.5    |     1060    |
# | 2414600126 | 2015-04-15 00:00:00+00:00 |  229500 |    3     |     1     |     1780    |
# | 3793500160 | 2015-03-12 00:00:00+00:00 |  323000 |    3     |    2.5    |     1890    |
# +------------+---------------------------+---------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |   5650   |   1    |     0      |  0   |     3     |   7   |    1180    |       0       |
# |   7242   |   2    |     0      |  0   |     3     |   7   |    2170    |      400      |
# |  10000   |   1    |     0      |  0   |     3     |   6   |    770     |       0       |
# |   5000   |   1    |     0      |  0   |     5     |   7   |    1050    |      910      |
# |   8080   |   1    |     0      |  0   |     3     |   8   |    1680    |       0       |
# |  101930  |   1    |     0      |  0   |     3     |   11  |    3890    |      1530     |
# |   6819   |   2    |     0      |  0   |     3     |   7   |    1715    |       0       |
# |   9711   |   1    |     0      |  0   |     3     |   7   |    1060    |       0       |
# |   7470   |   1    |     0      |  0   |     3     |   7   |    1050    |      730      |
# |   6560   |   2    |     0      |  0   |     3     |   7   |    1890    |       0       |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1955   |      0       |  98178  | 47.51123398 | -122.25677536 |     1340.0    | ... |
# |   1951   |     1991     |  98125  | 47.72102274 |  -122.3188624 |     1690.0    | ... |
# |   1933   |      0       |  98028  | 47.73792661 | -122.23319601 |     2720.0    | ... |
# |   1965   |      0       |  98136  |   47.52082  | -122.39318505 |     1360.0    | ... |
# |   1987   |      0       |  98074  | 47.61681228 | -122.04490059 |     1800.0    | ... |
# |   2001   |      0       |  98053  | 47.65611835 | -122.00528655 |     4760.0    | ... |
# |   1995   |      0       |  98003  | 47.30972002 | -122.32704857 |     2238.0    | ... |
# |   1963   |      0       |  98198  | 47.40949984 | -122.31457273 |     1650.0    | ... |
# |   1960   |      0       |  98146  | 47.51229381 | -122.33659507 |     1780.0    | ... |
# |   2003   |      0       |  98038  | 47.36840673 |  -122.0308176 |     2390.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [21613 rows x 21 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Exploring tha data for the house

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view="Scatter Plot", x="sqft_living", y="price")

# %% [markdown]
# Creat a simple regression model of sqft_living to price

# %%
train_data,test_data = sales.random_split(.8,seed=0)

# %%
train
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000 |    4     |     3     |     1960    |
# | 1954400510 | 2015-02-18 00:00:00+00:00 |  510000 |    3     |     2     |     1680    |
# | 7237550310 | 2014-05-12 00:00:00+00:00 | 1225000 |    4     |    4.5    |     5420    |
# | 1321400060 | 2014-06-27 00:00:00+00:00 |  257500 |    3     |    2.25   |     1715    |
# | 2008000270 | 2015-01-15 00:00:00+00:00 |  291850 |    3     |    1.5    |     1060    |
# | 2414600126 | 2015-04-15 00:00:00+00:00 |  229500 |    3     |     1     |     1780    |
# | 3793500160 | 2015-03-12 00:00:00+00:00 |  323000 |    3     |    2.5    |     1890    |
# +------------+---------------------------+---------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |   5650   |   1    |     0      |  0   |     3     |   7   |    1180    |       0       |
# |   7242   |   2    |     0      |  0   |     3     |   7   |    2170    |      400      |
# |  10000   |   1    |     0      |  0   |     3     |   6   |    770     |       0       |
# |   5000   |   1    |     0      |  0   |     5     |   7   |    1050    |      910      |
# |   8080   |   1    |     0      |  0   |     3     |   8   |    1680    |       0       |
# |  101930  |   1    |     0      |  0   |     3     |   11  |    3890    |      1530     |
# |   6819   |   2    |     0      |  0   |     3     |   7   |    1715    |       0       |
# |   9711   |   1    |     0      |  0   |     3     |   7   |    1060    |       0       |
# |   7470   |   1    |     0      |  0   |     3     |   7   |    1050    |      730      |
# |   6560   |   2    |     0      |  0   |     3     |   7   |    1890    |       0       |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1955   |      0       |  98178  | 47.51123398 | -122.25677536 |     1340.0    | ... |
# |   1951   |     1991     |  98125  | 47.72102274 |  -122.3188624 |     1690.0    | ... |
# |   1933   |      0       |  98028  | 47.73792661 | -122.23319601 |     2720.0    | ... |
# |   1965   |      0       |  98136  |   47.52082  | -122.39318505 |     1360.0    | ... |
# |   1987   |      0       |  98074  | 47.61681228 | -122.04490059 |     1800.0    | ... |
# |   2001   |      0       |  98053  | 47.65611835 | -122.00528655 |     4760.0    | ... |
# |   1995   |      0       |  98003  | 47.30972002 | -122.32704857 |     2238.0    | ... |
# |   1963   |      0       |  98198  | 47.40949984 | -122.31457273 |     1650.0    | ... |
# |   1960   |      0       |  98146  | 47.51229381 | -122.33659507 |     1780.0    | ... |
# |   2003   |      0       |  98038  | 47.36840673 |  -122.0308176 |     2390.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [? rows x 21 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use len(sf) to force materialization.

# %%
test
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+--------+----------+-----------+-------------+
# |     id     |            date           | price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+--------+----------+-----------+-------------+
# | 0114101516 | 2014-05-28 00:00:00+00:00 | 310000 |    3     |     1     |     1430    |
# | 9297300055 | 2015-01-24 00:00:00+00:00 | 650000 |    4     |     3     |     2950    |
# | 1202000200 | 2014-11-03 00:00:00+00:00 | 233000 |    3     |     2     |     1710    |
# | 8562750320 | 2014-11-10 00:00:00+00:00 | 580500 |    3     |    2.5    |     2320    |
# | 7589200193 | 2014-11-10 00:00:00+00:00 | 535000 |    3     |     1     |     1090    |
# | 2078500320 | 2014-06-20 00:00:00+00:00 | 605000 |    4     |    2.5    |     2620    |
# | 7766200013 | 2014-08-11 00:00:00+00:00 | 775000 |    4     |    2.25   |     4220    |
# | 9478500640 | 2014-08-19 00:00:00+00:00 | 292500 |    4     |    2.5    |     2250    |
# | 9558200045 | 2014-08-28 00:00:00+00:00 | 289000 |    3     |    1.75   |     1260    |
# | 8820901275 | 2014-06-10 00:00:00+00:00 | 571000 |    4     |     2     |     2750    |
# +------------+---------------------------+--------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |  19901   |  1.5   |     0      |  0   |     4     |   7   |    1430    |       0       |
# |   5000   |   2    |     0      |  3   |     3     |   9   |    1980    |      970      |
# |   4697   |  1.5   |     0      |  0   |     5     |   6   |    1710    |       0       |
# |   3980   |   2    |     0      |  0   |     3     |   8   |    2320    |       0       |
# |   3000   |  1.5   |     0      |  0   |     4     |   8   |    1090    |       0       |
# |   7553   |   2    |     0      |  0   |     3     |   8   |    2620    |       0       |
# |  24186   |   1    |     0      |  0   |     3     |   8   |    2600    |      1620     |
# |   4495   |   2    |     0      |  0   |     3     |   7   |    2250    |       0       |
# |   8400   |   1    |     0      |  0   |     3     |   7   |    1260    |       0       |
# |   7807   |  1.5   |     0      |  0   |     5     |   7   |    2250    |      500      |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1927   |      0       |  98028  | 47.75584254 | -122.22874498 |     1780.0    | ... |
# |   1979   |      0       |  98126  | 47.57136955 | -122.37541218 |     2140.0    | ... |
# |   1941   |      0       |  98002  | 47.30482931 | -122.21774909 |     1030.0    | ... |
# |   2003   |      0       |  98027  |  47.5391103 | -122.06971484 |     2580.0    | ... |
# |   1929   |      0       |  98117  | 47.68889559 |  -122.3752359 |     1570.0    | ... |
# |   1996   |      0       |  98056  | 47.53013988 | -122.18000831 |     2620.0    | ... |
# |   1984   |      0       |  98166  | 47.44504345 | -122.34720874 |     2410.0    | ... |
# |   2008   |      0       |  98042  | 47.36628767 | -122.11356981 |     2250.0    | ... |
# |   1954   |      0       |  98148  | 47.43658598 |  -122.3346675 |     1290.0    | ... |
# |   1916   |      0       |  98125  |  47.7168015 | -122.28694727 |     1510.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [? rows x 21 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use len(sf) to force materialization.

# %%
sqft_model = graphlab.linear_regression.create(train_data,target="price",features= ['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16560
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# | 1         | 2        | 0.012417     | 4351489.105258     | 3142747.845769       | 262863.334617 | 264556.758968   |
# +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print test_data['price'].mean()
# Out:
# 543054.042563

# %%
print sqft_model.evaluate(test_data)
# Out:
# {'max_error': 4145160.433530692, 'rmse': 255192.33913208617}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-eff513f636fd> in <module>()
# ----> 1 import matplotlib.pyplot as plt
#
# /Users/shabadlamba/anaconda/envs/dato-env/lib/python2.7/site-packages/matplotlib/pyplot.py in <module>()
#      27 from cycler import cycler
#      28 import matplotlib
# ---> 29 import matplotlib.colorbar
#      30 from matplotlib import style
#      31 from matplotlib import _pylab_helpers, interactive
#
# /Users/shabadlamba/anaconda/envs/dato-env/lib/python2.7/site-packages/matplotlib/colorbar.py in <module>()
#      30
#      31 import matplotlib as mpl
# ---> 32 import matplotlib.artist as martist
#      33 import matplotlib.cbook as cbook
#      34 import matplotlib.collections as collections
#
# /Users/shabadlamba/anaconda/envs/dato-env/lib/python2.7/site-packages/matplotlib/artist.py in <module>()
#       9 import numpy as np
#      10 import matplotlib
# ---> 11 import matplotlib.cbook as cbook
#      12 from matplotlib.cbook import mplDeprecation
#      13 from matplotlib import docstring, rcParams
#
# AttributeError: 'module' object has no attribute 'cbook'

# %%
import imp
imp.find_module("matplotlib")
# Out:
# (None,
#  '/Users/shabadlamba/anaconda/envs/dato-env/lib/python2.7/site-packages/matplotlib',
#  ('', '', 5))

# %%
sqft_model.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+---------------+
# |     name    | index |     value      |     stderr    |
# +-------------+-------+----------------+---------------+
# | (intercept) |  None | -47086.0986317 | 5048.26345031 |
# | sqft_living |  None | 281.792281608  | 2.21931685328 |
# +-------------+-------+----------------+---------------+
# [2 rows x 4 columns]
